# %%
import pandas as pd
import numpy as np
import matplotlib

import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

# %%
# Store filepath in a variable
file = "Issued_Construction_Permits_New.csv"

# %%
file_df = pd.read_csv(file)
file_df.head()
# Out:
#          PermitTypeDesc PermitClassMapped                 PermitClass  \
# 0  Driveway / Sidewalks       Residential    Res. Driveway & Sidewalk
# 1       Plumbing Permit       Residential                 Residential
# 2       Plumbing Permit       Residential  R- 435 Renovations/Remodel
# 3     Electrical Permit       Residential                 Residential
# 4       Plumbing Permit       Residential  R- 102 Secondary Apartment
#
#    FiscalYearIssued  OriginalZip
# 0              2018      78704.0
# 1              2018      78757.0
# 2              2018      78758.0
# 3              2018      78746.0
# 4              2018      78702.0

# %%
new_df = file_df[['FiscalYearIssued','OriginalZip']] 
new_df
# Out:
#        FiscalYearIssued  OriginalZip
# 0                  2018      78704.0
# 1                  2018      78757.0
# 2                  2018      78758.0
# 3                  2018      78746.0
# 4                  2018      78702.0
# 5                  2018      78759.0
# 6                  2018      78741.0
# 7                  2018      78754.0
# 8                  2018      78744.0
# 9                  2018      78759.0
# 10                 2018      78701.0
# 11                 2018      78739.0
# 12                 2018      78747.0
# 13                 2018      78758.0
# 14                 2018      78730.0
# 15                 2018      78725.0
# 16                 2018      78703.0
# 17                 2018      78652.0
# 18                 2018      78744.0
# 19                 2018      78758.0
# 20                 2018      78753.0
# 21                 2018      78703.0
# 22                 2018      78745.0
# 23                 2018      78759.0
# ...

# %%
final_df = new_df.groupby(['OriginalZip'])['FiscalYearIssued'].count().reset_index()
final_df["OriginalZip"]
final_df.sort_values(by = ["FiscalYearIssued"],ascending=False)
# Out:
#     OriginalZip  FiscalYearIssued
# 10      78704.0              2907
# 35      78744.0              2457
# 16      78723.0              2387
# 36      78745.0              2361
# 8       78702.0              2220
# 39      78748.0              1972
# 7       78701.0              1852
# 9       78703.0              1782
# 47      78757.0              1614
# 33      78741.0              1606
# 24      78731.0              1465
# 12      78717.0              1457
# 45      78754.0              1444
# 49      78759.0              1396
# 44      78753.0              1344
# 37      78746.0              1321
# 5       78660.0              1197
# 48      78758.0              1193
# 38      78747.0              1085
# 14      78721.0              1040
# 40      78749.0               926
# 20      78727.0               834
# 11      78705.0               770
# 43      78752.0               760
# 41      78750.0               747
# 17      78724.0               707
# ...
